# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
score = pd.read_csv('dogs-vs-cats-redux-kernels-edition-publicleaderboard.csv')
score.sort_values(by= 'Score',inplace=True)
top_10 = score[:int(score.shape[0]*0.1)]
top_10
# np.percentile(score['Score'], q=0.1)
# Out:
#       TeamId          TeamName       SubmissionDate    Score
# 4241  444682        Cocostarcu  2017-03-02 23:43:18  0.03302
# 4055  459493          guangsha  2017-03-01 08:01:34  0.03305
# 4203  444682        Cocostarcu  2017-03-02 18:35:44  0.03314
# 4049  444682        Cocostarcu  2017-03-01 07:33:16  0.03351
# 4050  459493          guangsha  2017-03-01 07:40:01  0.03375
# 3580  459493          guangsha  2017-02-22 00:27:37  0.03409
# 4048  444682        Cocostarcu  2017-03-01 07:05:24  0.03446
# 4244  467608            malr87  2017-03-02 23:57:59  0.03483
# 3965  444682        Cocostarcu  2017-02-28 07:02:27  0.03485
# 4033  467608            malr87  2017-03-01 02:31:49  0.03500
# 4187  368495      Bojan Tunguz  2017-03-02 15:44:08  0.03507
# 4023  368495      Bojan Tunguz  2017-03-01 00:20:30  0.03508
# 4024  368495      Bojan Tunguz  2017-03-01 00:24:46  0.03508
# 3999  368495      Bojan Tunguz  2017-02-28 15:51:11  0.03509
# ...

# %%
import sys
sys.path
# Out:
# ['',
#  'E:\\Python\\MLND\\Dogs_vs_Cats',
#  'c:\\users\\tyelcie\\appdata\\local\\programs\\python\\python37\\python37.zip',
#  'c:\\users\\tyelcie\\appdata\\local\\programs\\python\\python37\\DLLs',
#  'c:\\users\\tyelcie\\appdata\\local\\programs\\python\\python37\\lib',
#  'c:\\users\\tyelcie\\appdata\\local\\programs\\python\\python37',
#  'C:\\Users\\Tyelcie\\AppData\\Roaming\\Python\\Python37\\site-packages',
#  'c:\\users\\tyelcie\\appdata\\local\\programs\\python\\python37\\lib\\site-packages',
#  'c:\\users\\tyelcie\\appdata\\local\\programs\\python\\python37\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\Tyelcie\\.ipython']
